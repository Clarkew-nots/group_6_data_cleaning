# %%
import pandas as pd
import numpy as np


# Read in csv
df = pd.read_csv("../data/Students_admission_records.csv")

# %%
df.head()
# Out:
#       Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0  Shehroz  24.0  Female                  50.0                   68.90
# 1    Waqar  21.0  Female                  99.0                   60.73
# 2   Bushra  17.0    Male                  89.0                     NaN
# 3    Aliya  17.0    Male                  55.0                   85.29
# 4    Bilal  20.0    Male                  65.0                   61.13
#
#         City Admission Status
# 0     Quetta         Rejected
# 1    Karachi              NaN
# 2  Islamabad         Accepted
# 3    Karachi         Rejected
# 4     Lahore              NaN

# %%
df.info()
df.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    147 non-null    str
#  1   Age                     147 non-null    float64
#  2   Gender                  147 non-null    str
#  3   Admission Test Score    146 non-null    float64
#  4   High School Percentage  146 non-null    float64
#  5   City                    147 non-null    str
#  6   Admission Status        147 non-null    str
# dtypes: float64(3), str(4)
# memory usage: 8.7 KB
# Index(['Name', 'Age', 'Gender', 'Admission Test Score',
#        'High School Percentage', 'City', 'Admission Status'],
#       dtype='str')

# %%
df = df.drop_duplicates()

# %%
df = df.drop(columns=["City", "Name"])

# %%
df.head()
# Out:
#     Age  Gender  Admission Test Score  High School Percentage Admission Status
# 0  24.0  Female                  50.0                   68.90         Rejected
# 1  21.0  Female                  99.0                   60.73              NaN
# 2  17.0    Male                  89.0                     NaN         Accepted
# 3  17.0    Male                  55.0                   85.29         Rejected
# 4  20.0    Male                  65.0                   61.13              NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 151 entries, 0 to 156
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     141 non-null    float64
#  1   Gender                  141 non-null    str
#  2   Admission Test Score    140 non-null    float64
#  3   High School Percentage  140 non-null    float64
#  4   Admission Status        141 non-null    str
# dtypes: float64(3), str(2)
# memory usage: 7.1 KB

# %%
df["Admission Test Score"] = df["Admission Test Score"][(df["Admission Test Score"] >= 0) & (df["Admission Test Score"] <= 100)]
df["High School Percentage"] = df["High School Percentage"][(df["High School Percentage"] >= 0) & (df["High School Percentage"] <= 100)]

# %%
df.head(26)
# Out:
#      Age  Gender  Admission Test Score  High School Percentage  \
# 0   24.0  Female                  50.0                   68.90
# 1   21.0  Female                  99.0                   60.73
# 2   17.0    Male                  89.0                     NaN
# 3   17.0    Male                  55.0                   85.29
# 4   20.0    Male                  65.0                   61.13
# 5   23.0  Female                   NaN                     NaN
# 6   18.0    Male                   NaN                   97.31
# 7   20.0  Female                  82.0                   55.67
# 8   17.0    Male                  64.0                     NaN
# 9   18.0    Male                  53.0                   98.98
# 10  17.0    Male                  78.0                     NaN
# 11  18.0    Male                  89.0                     NaN
# 12  19.0    Male                  66.0                   88.17
# 13  21.0    Male                  62.0                   79.03
# ...
